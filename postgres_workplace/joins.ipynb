# %%
import psycopg2
from sqlalchemy import create_engine

# %%
def get_engine(user, password, host, port, database):
    """
    Returns an engine to the database
    """
    return create_engine('postgresql://{}:{}@{}:{}/{}'.format(user, password, host, port, database))

engine = get_engine(input("enter user: "), input("enter password: "), 'localhost', 5432, 'dvd_rental')
print(engine)
# Out:
# Engine(postgresql://rob_the_programmer:***@localhost:5432/dvd_rental)

# %%
engine.execute("SELECT version()").fetchone()
# Out:
# ('PostgreSQL 9.5.25 on x86_64-apple-darwin21.1.0, compiled by Apple clang version 13.0.0 (clang-1300.0.29.3), 64-bit',)

# %%
import pandas as pd

# %%
# test the database connection
df = pd.read_sql_query("SELECT * FROM actor LIMIT 20;", engine)
print(df)
# Out:
#     actor_id first_name     last_name             last_update
# 0          1   Penelope       Guiness 2013-05-26 14:47:57.620
# 1          2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 2          3         Ed         Chase 2013-05-26 14:47:57.620
# 3          4   Jennifer         Davis 2013-05-26 14:47:57.620
# 4          5     Johnny  Lollobrigida 2013-05-26 14:47:57.620
# 5          6      Bette     Nicholson 2013-05-26 14:47:57.620
# 6          7      Grace        Mostel 2013-05-26 14:47:57.620
# 7          8    Matthew     Johansson 2013-05-26 14:47:57.620
# 8          9        Joe         Swank 2013-05-26 14:47:57.620
# 9         10  Christian         Gable 2013-05-26 14:47:57.620
# 10        11       Zero          Cage 2013-05-26 14:47:57.620
# 11        12       Karl         Berry 2013-05-26 14:47:57.620
# 12        13        Uma          Wood 2013-05-26 14:47:57.620
# 13        14     Vivien        Bergen 2013-05-26 14:47:57.620
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %%
# example of a join: get the customer email associated with a specific payment
engine.execute(
    """
    select payment_id, payment.customer_id, first_name 
        from payment 
            inner join customer 
            on payment.customer_id = customer.customer_id;
    """
).fetchall()
# Out:
# [(17503, 341, 'Peter'),
#  (17504, 341, 'Peter'),
#  (17505, 341, 'Peter'),
#  (17506, 341, 'Peter'),
#  (17507, 341, 'Peter'),
#  (17508, 341, 'Peter'),
#  (17509, 342, 'Harold'),
#  (17510, 342, 'Harold'),
#  (17511, 342, 'Harold'),
#  (17512, 343, 'Douglas'),
#  (17513, 343, 'Douglas'),
#  (17514, 343, 'Douglas'),
#  (17515, 343, 'Douglas'),
#  (17516, 343, 'Douglas'),
#  (17517, 343, 'Douglas'),
#  (17518, 343, 'Douglas'),
#  (17519, 344, 'Henry'),
#  (17520, 344, 'Henry'),
#  (17521, 344, 'Henry'),
#  (17522, 345, 'Carl'),
#  (17523, 345, 'Carl'),
#  (17524, 345, 'Carl'),
#  (17525, 345, 'Carl'),
#  (17526, 346, 'Arthur'),
#  (17527, 346, 'Arthur'),
#  (17528, 346, 'Arthur'),
#  (17529, 347, 'Ryan'),
#  (17530, 347, 'Ryan'),
#  (17531, 347, 'Ryan'),
#  (17532, 347, 'Ryan'),
#  (17533, 347, 'Ryan'),
#  (17534, 348, 'Roger'),
#  (17535, 348, 'Roger'),
#  (17536, 348, 'Roger'),
#  (17537, 349, 'Joe'),
#  (17538, 349, 'Joe'),
#  (17539, 349, 'Joe'),
#  (17540, 349, 'Joe'),
# ...

# %%
df_inner_join = pd.read_sql_query("""
select payment_id, payment.customer_id, first_name 
    from payment 
    inner join customer 
    on payment.customer_id = customer.customer_id;
"""
, engine)
df_inner_join
# Out:
#        payment_id  customer_id first_name
# 0           17503          341      Peter
# 1           17504          341      Peter
# 2           17505          341      Peter
# 3           17506          341      Peter
# 4           17507          341      Peter
# ...           ...          ...        ...
# 14591       32094          245   Courtney
# 14592       32095          251     Vickie
# 14593       32096          252     Mattie
# 14594       32097          263      Hilda
# 14595       32098          264  Gwendolyn
#
# [14596 rows x 3 columns]

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------

# %%
# full outer join example: deal with values only present in one table
engine.execute(
    """
    SELECT * FROM customer c 
    FULL OUTER JOIN payment p 
    ON c.customer_id = p.customer_id LIMIT 5;
    """
, engine).fetchall()
# Out:
# [(1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 18495, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2007, 2, 14, 23, 22, 38, 996577)),
#  (1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 18496, 1, 2, 1422, Decimal('0.99'), datetime.datetime(2007, 2, 15, 16, 31, 19, 996577)),
#  (1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 18497, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2007, 2, 15, 19, 37, 12, 996577)),
#  (1, 1, 'Mary', 'Smith', 'mary.smith@sakilacustomer.org', 5, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 18498, 1, 1, 1725, Decimal('4.99'), datetime.datetime(2007, 2, 16, 13, 47, 23, 996577)),
# ...

# %%
engine.execute(
    """
    SELECT * FROM customer c 
    FULL OUTER JOIN payment p 
    ON c.customer_id = p.customer_id
    WHERE c.customer_id IS NULL OR p.payment_id IS NULL;
    """
, engine).fetchall()
# Out:
# []

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %%
# a left outer join results in the set of records that are in the left table,
# if there is no match in the right table, the right table is padded with nulls
engine.execute("""
    SELECT * FROM customer c
    LEFT OUTER JOIN payment p
    ON c.customer_id = p.customer_id LIMIT 10;
    """,
engine).fetchall()
# Out:
# [(524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 18202, 524, 1, 1306, Decimal('1.99'), datetime.datetime(2007, 2, 15, 8, 27, 50, 996577)),
#  (524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 18203, 524, 2, 1651, Decimal('4.99'), datetime.datetime(2007, 2, 16, 7, 53, 4, 996577)),
#  (524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 18204, 524, 2, 3454, Decimal('2.99'), datetime.datetime(2007, 2, 21, 19, 40, 39, 996577)),
#  (524, 1, 'Jared', 'Ely', 'jared.ely@sakilacustomer.org', 530, True, datetime.date(2006, 2, 14), datetime.datetime(2013, 5, 26, 14, 49, 45, 738000), 1, 21950, 524, 2, 13626, Decimal('2.99'), datetime.datetime(2007, 3, 20, 5, 23, 50, 996577)),
# ...

# %%
df_left_outer_join = pd.read_sql_query("""
                                        SELECT * FROM customer c
                                            LEFT OUTER JOIN payment p
                                            ON c.customer_id = p.customer_id;""", engine)
df_left_outer_join
# Out:
#        customer_id  store_id first_name last_name  \
# 0              341         1      Peter    Menard
# 1              341         1      Peter    Menard
# 2              341         1      Peter    Menard
# 3              341         1      Peter    Menard
# 4              341         1      Peter    Menard
# ...            ...       ...        ...       ...
# 14591          245         1   Courtney       Day
# 14592          251         2     Vickie    Brewer
# 14593          252         2     Mattie   Hoffman
# 14594          263         1      Hilda   Hopkins
# 14595          264         1  Gwendolyn       May
#
#                                    email  address_id  activebool create_date  \
# 0        peter.menard@sakilacustomer.org         346        True  2006-02-14
# 1        peter.menard@sakilacustomer.org         346        True  2006-02-14
# 2        peter.menard@sakilacustomer.org         346        True  2006-02-14
# ...

# %%
engine.execute("""
    SELECT f.film_id, f.title, i.inventory_id, i.store_id
    FROM film f
    LEFT OUTER JOIN inventory i
    ON i.film_id = f.film_id
    WHERE i.film_id IS NULL;
    ;
    """, engine).fetchall()
# Out:
# [(14, 'Alice Fantasia', None, None),
#  (33, 'Apollo Teen', None, None),
#  (36, 'Argonauts Town', None, None),
#  (38, 'Ark Ridgemont', None, None),
#  (41, 'Arsenic Independence', None, None),
#  (87, 'Boondock Ballroom', None, None),
#  (108, 'Butch Panther', None, None),
#  (128, 'Catch Amistad', None, None),
#  (144, 'Chinatown Gladiator', None, None),
#  (148, 'Chocolate Duck', None, None),
#  (171, 'Commandments Express', None, None),
#  (192, 'Crossing Divorce', None, None),
#  (195, 'Crowds Telemark', None, None),
#  (198, 'Crystal Breaking', None, None),
#  (217, 'Dazed Punk', None, None),
#  (221, 'Deliverance Mulholland', None, None),
#  (318, 'Firehouse Vietnam', None, None),
#  (325, 'Floats Garden', None, None),
#  (332, 'Frankenstein Stranger', None, None),
#  (359, 'Gladiator Westward', None, None),
#  (386, 'Gump Date', None, None),
#  (404, 'Hate Handicap', None, None),
#  (419, 'Hocus Frida', None, None),
#  (495, 'Kentuckian Giant', None, None),
# ...

# %% [markdown]
# ______________________________________________________________________________________________________________________

# %%
# a right join is the same as left join except the tables are switched
engine.execute("""
    SELECT f.film_id, f.title, i.inventory_id, i.store_id
    FROM film f
    RIGHT OUTER JOIN inventory i
    ON CASE
        WHEN i.film_id IS NULL THEN f.film_id
        ELSE i.film_id
    END = f.film_id
    
    ;
    """, engine).fetchall()
# Out:
# [(1, 'Academy Dinosaur', 1, 1),
#  (1, 'Academy Dinosaur', 2, 1),
#  (1, 'Academy Dinosaur', 3, 1),
#  (1, 'Academy Dinosaur', 4, 1),
#  (1, 'Academy Dinosaur', 5, 2),
#  (1, 'Academy Dinosaur', 6, 2),
#  (1, 'Academy Dinosaur', 7, 2),
#  (1, 'Academy Dinosaur', 8, 2),
#  (2, 'Ace Goldfinger', 9, 2),
#  (2, 'Ace Goldfinger', 10, 2),
#  (2, 'Ace Goldfinger', 11, 2),
#  (3, 'Adaptation Holes', 12, 2),
#  (3, 'Adaptation Holes', 13, 2),
#  (3, 'Adaptation Holes', 14, 2),
#  (3, 'Adaptation Holes', 15, 2),
#  (4, 'Affair Prejudice', 16, 1),
#  (4, 'Affair Prejudice', 17, 1),
#  (4, 'Affair Prejudice', 18, 1),
#  (4, 'Affair Prejudice', 19, 1),
#  (4, 'Affair Prejudice', 20, 2),
#  (4, 'Affair Prejudice', 21, 2),
#  (4, 'Affair Prejudice', 22, 2),
#  (5, 'African Egg', 23, 2),
#  (5, 'African Egg', 24, 2),
#  (5, 'African Egg', 25, 2),
#  (6, 'Agent Truman', 26, 1),
#  (6, 'Agent Truman', 27, 1),
#  (6, 'Agent Truman', 28, 1),
#  (6, 'Agent Truman', 29, 2),
#  (6, 'Agent Truman', 30, 2),
# ...

# %%
df_right_outer_join = pd.read_sql_query("""
    SELECT f.film_id, f.title, i.inventory_id, i.store_id
    FROM film f
    RIGHT OUTER JOIN inventory i
    ON CASE
        WHEN i.film_id IS NULL THEN f.film_id
        ELSE i.film_id
    END = f.film_id
    
    ;
    """, engine)
print(df_right_outer_join)
# Out:
#       film_id             title  inventory_id  store_id
# 0           1  Academy Dinosaur             1         1
# 1           1  Academy Dinosaur             2         1
# 2           1  Academy Dinosaur             3         1
# 3           1  Academy Dinosaur             4         1
# 4           1  Academy Dinosaur             5         2
# ...       ...               ...           ...       ...
# 4576     1000         Zorro Ark          4577         1
# 4577     1000         Zorro Ark          4578         2
# 4578     1000         Zorro Ark          4579         2
# 4579     1000         Zorro Ark          4580         2
# 4580     1000         Zorro Ark          4581         2
#
# [4581 rows x 4 columns]

# %% [markdown]
# ______________________________________________________________________________________________________________________

# %%
# what are the names and emails of customers who live in California?
df1 = pd.read_sql_query(
    """
        SELECT c.first_name, c.last_name, c.email, a.district 
        FROM customer c 
            INNER JOIN address a 
                ON a.address_id = c.address_id 
        WHERE a.district = 'California';
    """
    , engine)
print(df1)
# Out:
#   first_name  last_name                                 email    district
# 0   Patricia    Johnson   patricia.johnson@sakilacustomer.org  California
# 1      Betty      White        betty.white@sakilacustomer.org  California
# 2      Alice    Stewart      alice.stewart@sakilacustomer.org  California
# 3       Rosa   Reynolds      rosa.reynolds@sakilacustomer.org  California
# 4      Renee       Lane         renee.lane@sakilacustomer.org  California
# 5    Kristin   Johnston   kristin.johnston@sakilacustomer.org  California
# 6  Cassandra    Walters  cassandra.walters@sakilacustomer.org  California
# 7      Jacob      Lance        jacob.lance@sakilacustomer.org  California
# 8       Rene  Mcalister     rene.mcalister@sakilacustomer.org  California

# %%
# get a list of all the movies Nick Wahlberg has ever been in
df2 = pd.read_sql_query(
    """
        SELECT 
            f.title AS Movie, 
            a.first_name AS FirstName, 
            a.last_name AS LastName
        FROM 
            film_actor fa
        INNER JOIN actor a
        ON fa.actor_id = a.actor_id
        INNER JOIN film f
        ON fa.film_id = f.film_id
        WHERE a.first_name = 'Nick' AND last_name = 'Wahlberg';
    """
    , engine)
print(df2)
# Out:
#                 movie firstname  lastname
# 0    Adaptation Holes      Nick  Wahlberg
# 1       Apache Divine      Nick  Wahlberg
# 2           Baby Hall      Nick  Wahlberg
# 3      Bull Shawshank      Nick  Wahlberg
# 4     Chainsaw Uptown      Nick  Wahlberg
# 5     Chisum Behavior      Nick  Wahlberg
# 6    Destiny Saturday      Nick  Wahlberg
# 7     Dracula Crystal      Nick  Wahlberg
# 8    Fight Jawbreaker      Nick  Wahlberg
# 9          Flash Wars      Nick  Wahlberg
# 10    Gilbert Pelican      Nick  Wahlberg
# 11  Goodfellas Salute      Nick  Wahlberg
# 12   Happiness United      Nick  Wahlberg
# 13        Indian Love      Nick  Wahlberg
# 14     Jekyll Frogmen      Nick  Wahlberg
# 15       Jersey Sassy      Nick  Wahlberg
# 16     Liaisons Sweet      Nick  Wahlberg
# 17       Lucky Flying      Nick  Wahlberg
# 18     Maguire Apache      Nick  Wahlberg
# 19    Mallrats United      Nick  Wahlberg
# 20         Mask Peach      Nick  Wahlberg
# ...

# %%
df2.movie.nunique()
# Out:
# 25

# %%
df2.isna().sum()
# Out:
# movie        0
# firstname    0
# lastname     0
# dtype: int64

# %%
df2.movie.value_counts()
# Out:
# Adaptation Holes     1
# Indian Love          1
# Smile Earring        1
# Rushmore Mermaid     1
# Roof Champion        1
# Mask Peach           1
# Mallrats United      1
# Maguire Apache       1
# Lucky Flying         1
# Liaisons Sweet       1
# Jersey Sassy         1
# Jekyll Frogmen       1
# Happiness United     1
# Apache Divine        1
# Goodfellas Salute    1
# Gilbert Pelican      1
# Flash Wars           1
# Fight Jawbreaker     1
# Dracula Crystal      1
# Destiny Saturday     1
# Chisum Behavior      1
# Chainsaw Uptown      1
# Bull Shawshank       1
# Baby Hall            1
# Wardrobe Phantom     1
# Name: movie, dtype: int64

# %%
df2.firstname.unique()
# Out:
# array(['Nick'], dtype=object)

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df2)
# Out:
# 25

# %%
df2.head(5)
# Out:
#               movie firstname  lastname
# 0  Adaptation Holes      Nick  Wahlberg
# 1     Apache Divine      Nick  Wahlberg
# 2         Baby Hall      Nick  Wahlberg
# 3    Bull Shawshank      Nick  Wahlberg
# 4   Chainsaw Uptown      Nick  Wahlberg

# %%
# find the movie with phantom in the title
df2[df2.movie.str.contains('phantom'.title())]
# Out:
#                movie firstname  lastname
# 24  Wardrobe Phantom      Nick  Wahlberg

# %% [markdown]
# _____________________________________________________________________________________________________________________

# %% [markdown]
# SELF-JOIN: A QUERY IN WHICH A TABLE IS JOINED TO ITSELF. SELF-JOINS ARE USEFUL FOR COMPARING VALUES.

# %%
query = """
    select 
        a.district, 
        b.address 
    from address as a 
    join address as b 
    on a.address_id = b.city_id limit 10;
"""

df = pd.read_sql_query(query, engine)
print(df)
# Out:
#      district                   address
# 0     Alberta      939 Probolinggo Loop
# 1         QLD     733 Mandaluyong Place
# 2     Alberta      535 Ahmadnagar Manor
# 3         QLD  1789 Saint-Denis Parkway
# 4    Nagasaki   663 Baha Blanca Parkway
# 5  California       614 Pak Kret Street
# 6      Attika             751 Lima Loop
# 7    Mandalay           230 Urawa Drive
# 8      Nantou       922 Vila Velha Loop
# 9       Texas     923 Tangail Boulevard

# %%
# find all the pairs of films that have the same length
query = """
    select 
        f1.title, 
        f2.title,
        f1.length
    from film as f1
    join film as f2
    on f1.film_id != f2.film_id and f1.length = f2.length;
"""

df = pd.read_sql_query(query, engine)
print(df)
# Out:
#                  title                   title  length
# 0      Chamber Italian  Resurrection Silverado     117
# 1      Chamber Italian          Magic Mallrats     117
# 2      Chamber Italian           Graffiti Love     117
# 3      Chamber Italian        Affair Prejudice     117
# 4     Grosse Wonderful        Hurricane Affair      49
# ...                ...                     ...     ...
# 6967         Zorro Ark             Muppet Mile      50
# 6968         Zorro Ark              Lion Uncut      50
# 6969         Zorro Ark        Crossing Divorce      50
# 6970         Zorro Ark          Blues Instinct      50
# 6971         Zorro Ark        Adaptation Holes      50
#
# [6972 rows x 3 columns]
